# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import random

# %%
#Mounting drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#adding 26 column names and reading the .txt file
dep_var=['RUL']
input_file_column_names=['e_id','cycle','oprsetting1','oprsetting2','oprsetting3','sensor1','sensor2','sensor3','sensor4','sensor5','sensor6','sensor7','sensor8','sensor9','sensor10','sensor11','sensor12','sensor13','sensor14','sensor15','sensor16','sensor17','sensor18','sensor19','sensor20','sensor21']
path="/content/drive/MyDrive/RUL_Dataset/train.txt"
train = pd.read_csv(path,delim_whitespace=True, names=input_file_column_names)
print('DATA SHAPE: ', train.shape)
# Out:
# DATA SHAPE:  (45918, 26)

# %%
#showing first five rows of the data before adding the rul column
train.head()
# Out:
#    e_id  cycle  oprsetting1  oprsetting2  oprsetting3  sensor1  sensor2  \
# 0     1      1      10.0047       0.2501         20.0   489.05   604.13
# 1     1      2       0.0015       0.0003        100.0   518.67   642.13
# 2     1      3      34.9986       0.8401         60.0   449.44   555.42
# 3     1      4      20.0031       0.7005          0.0   491.19   607.03
# 4     1      5      42.0041       0.8405         40.0   445.00   549.52
#
#    sensor3  sensor4  sensor5  ...  sensor12  sensor13  sensor14  sensor15  \
# 0  1499.45  1309.95    10.52  ...    372.15   2388.13   8120.83    8.6216
# 1  1584.55  1403.96    14.62  ...    521.81   2388.15   8132.87    8.3907
# 2  1368.17  1122.49     5.48  ...    183.26   2387.95   8063.84    9.3557
# 3  1488.44  1249.18     9.35  ...    314.84   2388.07   8052.30    9.2231
# 4  1354.48  1124.32     3.91  ...    130.44   2387.89   8083.67    9.2986
#
#    sensor16  sensor17  sensor18  sensor19  sensor20  sensor21
# 0      0.03       368      2319     100.0     28.58   17.1735
# 1      0.03       391      2388     100.0     38.99   23.3619
# 2      0.02       334      2223     100.0     14.83    8.8555
# 3      0.02       364      2324     100.0     24.42   14.7832
# 4      0.02       330      2212     100.0     10.99    6.4025
#
# [5 rows x 26 columns]

# %%
#showing last five rows of the data before adding the rul column
train.tail()
# Out:
#        e_id  cycle  oprsetting1  oprsetting2  oprsetting3  sensor1  sensor2  \
# 45913   218    129      42.0066       0.8400         40.0   445.00   551.02
# 45914   218    130      42.0029       0.8415         40.0   445.00   550.07
# 45915   218    131      41.9999       0.8400         40.0   445.00   549.92
# 45916   218    132      35.0007       0.8419         60.0   449.44   556.55
# 45917   218    133      25.0071       0.6216         80.0   462.54   537.46
#
#        sensor3  sensor4  sensor5  ...  sensor12  sensor13  sensor14  sensor15  \
# 45913  1365.27  1147.43     3.91  ...    130.21   2387.39   8062.87    9.4672
# 45914  1365.55  1142.21     3.91  ...    130.24   2387.28   8062.05    9.4619
# 45915  1359.21  1150.15     3.91  ...    129.86   2387.33   8062.73    9.4827
# 45916  1380.05  1145.49     5.48  ...    182.03   2387.56   8043.21    9.4212
# 45917  1274.65  1068.77     7.05  ...    164.18   2027.75   7859.24   10.9748
#
#        sensor16  sensor17  sensor18  sensor19  sensor20  sensor21
# 45913      0.02       333      2212    100.00     10.57    6.2985
# 45914      0.02       332      2212    100.00     10.40    6.2741
# 45915      0.02       334      2212    100.00     10.37    6.1978
# 45916      0.02       337      2223    100.00     14.70    8.6761
# 45917      0.02       310      1915     84.93     14.19    8.5120
#
# [5 rows x 26 columns]

# %%
train.describe()
# Out:
#                e_id         cycle   oprsetting1   oprsetting2   oprsetting3  \
# count  45918.000000  45918.000000  45918.000000  45918.000000  45918.000000
# mean     109.396511    110.307396     24.008881      0.571251     49.172438
# std       62.866193     68.420545     14.793676      0.310935     32.503659
# min        1.000000      1.000000      0.000000      0.000000      0.000000
# 25%       54.000000     53.000000     10.004500      0.250600     20.000000
# 50%      110.000000    106.000000     25.001500      0.700000     40.000000
# 75%      164.000000    160.000000     41.998100      0.840000     80.000000
# max      218.000000    357.000000     42.008000      0.842000    100.000000
#
#             sensor1       sensor2       sensor3       sensor4       sensor5  \
# count  45918.000000  45918.000000  45918.000000  45918.000000  45918.000000
# mean     472.861677    579.596770   1419.947816   1205.669194      8.029878
# std       26.460179     37.391068    106.286960    119.550936      3.627125
# min      445.000000    535.650000   1245.430000   1029.490000      3.910000
# 25%      445.000000    549.580000   1352.910000   1124.010000      3.910000
# 50%      462.540000    555.985000   1369.140000   1138.870000      7.050000
# 75%      491.190000    607.370000   1499.697500   1307.437500     10.520000
# max      518.670000    644.430000   1614.660000   1442.360000     14.620000
#
#        ...      sensor12      sensor13      sensor14      sensor15  \
# count  ...  45918.000000  45918.000000  45918.000000  45918.000000
# mean   ...    265.943344   2334.185381   8065.548831      9.332433
# std    ...    138.163656    128.426495     84.964099      0.751834
# min    ...    129.240000   2027.720000   7851.590000      8.325300
# 25%    ...    131.360000   2387.880000   8061.230000      8.676925
# 50%    ...    183.170000   2388.070000   8081.475000      9.314500
# 75%    ...    371.250000   2388.160000   8126.380000      9.390000
# max    ...    523.460000   2390.740000   8274.880000     11.082600
#
#            sensor16      sensor17      sensor18      sensor19      sensor20  \
# count  45918.000000  45918.000000  45918.000000  45918.000000  45918.000000
# mean       0.023354    348.293915   2228.342654     97.741699     20.776822
# std        0.004722     27.837602    145.693883      5.378969      9.903697
# min        0.020000    303.000000   1915.000000     84.930000     10.230000
# 25%        0.020000    331.000000   2212.000000    100.000000     10.840000
# 50%        0.020000    335.000000   2223.000000    100.000000     14.870000
# 75%        0.030000    369.000000   2324.000000    100.000000     28.470000
# max        0.030000    398.000000   2388.000000    100.000000     39.330000
#
#            sensor21
# count  45918.000000
# mean      12.466282
# std        5.941954
# min        6.126600
# 25%        6.504600
# 50%        8.925200
# 75%       17.084200
# max       23.590500
#
# [8 rows x 26 columns]

# %%
train['RUL']=''

# %%
train.head()
# Out:
#    e_id  cycle  oprsetting1  oprsetting2  oprsetting3  sensor1  sensor2  \
# 0     1      1      10.0047       0.2501         20.0   489.05   604.13
# 1     1      2       0.0015       0.0003        100.0   518.67   642.13
# 2     1      3      34.9986       0.8401         60.0   449.44   555.42
# 3     1      4      20.0031       0.7005          0.0   491.19   607.03
# 4     1      5      42.0041       0.8405         40.0   445.00   549.52
#
#    sensor3  sensor4  sensor5  ...  sensor13  sensor14  sensor15  sensor16  \
# 0  1499.45  1309.95    10.52  ...   2388.13   8120.83    8.6216      0.03
# 1  1584.55  1403.96    14.62  ...   2388.15   8132.87    8.3907      0.03
# 2  1368.17  1122.49     5.48  ...   2387.95   8063.84    9.3557      0.02
# 3  1488.44  1249.18     9.35  ...   2388.07   8052.30    9.2231      0.02
# 4  1354.48  1124.32     3.91  ...   2387.89   8083.67    9.2986      0.02
#
#    sensor17  sensor18  sensor19  sensor20  sensor21  RUL
# 0       368      2319     100.0     28.58   17.1735
# 1       391      2388     100.0     38.99   23.3619
# 2       334      2223     100.0     14.83    8.8555
# 3       364      2324     100.0     24.42   14.7832
# 4       330      2212     100.0     10.99    6.4025
#
# [5 rows x 27 columns]

# %%
input_file_column_names=['e_id','cycle','oprsetting1','oprsetting2','oprsetting3','sensor1','sensor2','sensor3','sensor4','sensor5','sensor6','sensor7','sensor8','sensor9','sensor10','sensor11','sensor12','sensor13','sensor14','sensor15','sensor16','sensor17','sensor18','sensor19','sensor20','sensor21']
path="/content/drive/MyDrive/RUL_Dataset/final_test.txt"
test = pd.read_csv(path,delim_whitespace=True, names=input_file_column_names)
print('DATA SHAPE: ', test.shape)
# Out:
# DATA SHAPE:  (55156, 26)

# %%
test.describe().T
# Out:
#                count         mean         std        min        25%  \
# e_id         55156.0   221.334488  124.539458     1.0000   116.0000
# cycle        55156.0    77.962035   55.441894     1.0000    32.0000
# oprsetting1  55156.0    24.005642   14.774840     0.0000    10.0045
# oprsetting2  55156.0     0.571366    0.310471     0.0000     0.2506
# oprsetting3  55156.0    49.078976   32.503164     0.0000    20.0000
# sensor1      55156.0   472.860462   26.418984   445.0000   445.0000
# sensor2      55156.0   579.429345   37.336312   535.5100   549.4700
# sensor3      55156.0  1418.007963  106.056670  1245.5700  1351.5000
# sensor4      55156.0  1202.571341  119.118778  1029.0300  1122.2600
# sensor5      55156.0     8.028791    3.620938     3.9100     3.9100
# sensor6      55156.0    11.593675    5.442899     5.7100     5.7200
# sensor7      55156.0   282.540092  146.408136   137.1400   139.7100
# sensor8      55156.0  2228.197028  145.710641  1914.9300  2211.8500
# sensor9      55156.0  8519.418538  336.065042  7988.0400  8319.4200
# sensor10     55156.0     1.095025    0.127770     0.9300     1.0200
# sensor11     55156.0    42.892743    3.234235    36.1800    41.8700
# sensor12     55156.0   265.997328  138.033491   129.4500   131.4000
# sensor13     55156.0  2333.963693  128.604651  2027.8100  2387.8800
# sensor14     55156.0  8062.779840   84.145773  7855.5000  8061.0700
# sensor15     55156.0     9.319049    0.750934     8.3320     8.6629
# sensor16     55156.0     0.023138    0.004641     0.0200     0.0200
# sensor17     55156.0   347.792715   27.782539   303.0000   330.0000
# sensor18     55156.0  2228.172094  145.819212  1915.0000  2212.0000
# sensor19     55156.0    97.734145    5.386359    84.9300   100.0000
# sensor20     55156.0    20.804601    9.904713    10.2500    10.8600
# sensor21     55156.0    12.483257    5.942881     6.0876     6.5125
#
#                     50%          75%        max
# e_id          223.00000   329.000000   435.0000
# cycle          68.00000   115.000000   298.0000
# oprsetting1    25.00140    41.998100    42.0080
# oprsetting2     0.70000     0.840000     0.8420
# oprsetting3    40.00000    80.000000   100.0000
# sensor1       462.54000   491.190000   518.6700
# sensor2       555.80000   607.250000   644.0800
# sensor3      1367.07000  1498.120000  1607.6100
# sensor4      1133.82000  1305.300000  1430.9500
# sensor5         7.05000    10.520000    14.6200
# sensor6         9.03000    15.490000    21.6100
# sensor7       194.72000   394.320000   555.9400
# sensor8      2223.02000  2323.940000  2388.3400
# sensor9      8354.50500  8775.780000  9181.2800
# sensor10        1.02000     1.260000     1.3000
# sensor11       42.23000    45.310000    48.2200
# sensor12      183.25000   371.460000   523.5100
# sensor13     2388.05000  2388.130000  2390.0800
# sensor14     8079.77000  8125.082500  8244.7200
# sensor15        9.30405     9.374700    11.0413
# sensor16        0.02000     0.030000     0.0300
# sensor17      334.00000   369.000000   398.0000
# sensor18     2223.00000  2324.000000  2388.0000
# sensor19      100.00000   100.000000   100.0000
# sensor20       14.89000    28.520000    39.4100
# sensor21        8.93680    17.111825    23.5903

# %%
test=test.drop([ 'sensor10', 'sensor15', 'sensor16',  'oprsetting2'], axis=1)

# %%
test.head(5)
# Out:
#    e_id  cycle  oprsetting1  oprsetting3  sensor1  sensor2  sensor3  sensor4  \
# 0     1      1      10.0047         20.0   489.05   605.02  1498.72  1304.90
# 1     1      2       0.0015        100.0   518.67   642.69  1592.90  1405.35
# 2     1      3      34.9986         60.0   449.44   555.49  1357.71  1127.52
# 3     1      4      20.0031          0.0   491.19   607.62  1479.86  1257.25
# 4     1      5      42.0041         40.0   445.00   549.69  1354.17  1124.17
#
#    sensor5  sensor6  ...  sensor9  sensor11  sensor12  sensor13  sensor14  \
# 0    10.52    15.49  ...  8770.87     45.47    371.83   2388.12   8128.58
# 1    14.62    21.61  ...  9046.61     47.46    521.88   2388.09   8128.07
# 2     5.48     8.00  ...  8340.55     41.80    182.97   2387.92   8060.07
# 3     9.35    13.65  ...  8721.01     44.22    315.29   2388.09   8060.00
# 4     3.91     5.72  ...  8318.64     41.98    130.50   2387.84   8080.66
#
#    sensor17  sensor18  sensor19  sensor20  sensor21
# 0       371      2319     100.0     28.52   17.0653
# 1       392      2388     100.0     38.95   23.3609
# 2       333      2223     100.0     14.91    8.8185
# 3       365      2324     100.0     24.35   14.7075
# 4       331      2212     100.0     10.67    6.4837
#
# [5 rows x 22 columns]

# %%
ntest = test.copy()

# %%
e_id = train['e_id'].unique()
train['MAX_CYCLE']=''
a = train.groupby ('e_id').size()
a
# df.loc[df['e_id']==1,'MAX_CYCLE']=a[1]
# df
# Out:
# e_id
# 1      223
# 2      164
# 3      150
# 4      159
# 5      357
#       ...
# 214    150
# 215    156
# 216    190
# 217    287
# 218    133
# Length: 218, dtype: int64

# %%
# #method1
# e_id = df['e_id'].unique()

# a = df.groupby ('e_id').size()
# for i in range(218):
#   df.loc[df['e_id']==i+1,'MAX_CYCLE']=a[i+1]
# df['RUL']=df['MAX_CYCLE']-df['cycle']
# df

# %%
#limiting rul to 120, so whatever id's cycle is greater than 120 it will be brought down to 120 or less.
#method2

MAX_LIFE=120
RUL = []
e_id = train['e_id'].unique()
for i in e_id:
  a = train[train['e_id']==e_id[i-1]]
  c = MAX_LIFE
  knee_point= len(a['cycle']) - MAX_LIFE
  for j in range(len(a['cycle'])):
    if j < knee_point:
      RUL.append(MAX_LIFE)
    else:
      c = c-1
      RUL.append(c)
train['RUL']= RUL

# %%
train
# Out:
#        e_id  cycle  oprsetting1  oprsetting2  oprsetting3  sensor1  sensor2  \
# 0         1      1      10.0047       0.2501         20.0   489.05   604.13
# 1         1      2       0.0015       0.0003        100.0   518.67   642.13
# 2         1      3      34.9986       0.8401         60.0   449.44   555.42
# 3         1      4      20.0031       0.7005          0.0   491.19   607.03
# 4         1      5      42.0041       0.8405         40.0   445.00   549.52
# ...     ...    ...          ...          ...          ...      ...      ...
# 45913   218    129      42.0066       0.8400         40.0   445.00   551.02
# 45914   218    130      42.0029       0.8415         40.0   445.00   550.07
# 45915   218    131      41.9999       0.8400         40.0   445.00   549.92
# 45916   218    132      35.0007       0.8419         60.0   449.44   556.55
# 45917   218    133      25.0071       0.6216         80.0   462.54   537.46
#
#        sensor3  sensor4  sensor5  ...  sensor14  sensor15  sensor16  sensor17  \
# 0      1499.45  1309.95    10.52  ...   8120.83    8.6216      0.03       368
# 1      1584.55  1403.96    14.62  ...   8132.87    8.3907      0.03       391
# 2      1368.17  1122.49     5.48  ...   8063.84    9.3557      0.02       334
# 3      1488.44  1249.18     9.35  ...   8052.30    9.2231      0.02       364
# 4      1354.48  1124.32     3.91  ...   8083.67    9.2986      0.02       330
# ...        ...      ...      ...  ...       ...       ...       ...       ...
# 45913  1365.27  1147.43     3.91  ...   8062.87    9.4672      0.02       333
# 45914  1365.55  1142.21     3.91  ...   8062.05    9.4619      0.02       332
# 45915  1359.21  1150.15     3.91  ...   8062.73    9.4827      0.02       334
# 45916  1380.05  1145.49     5.48  ...   8043.21    9.4212      0.02       337
# 45917  1274.65  1068.77     7.05  ...   7859.24   10.9748      0.02       310
#
#        sensor18  sensor19  sensor20  sensor21  RUL  MAX_CYCLE
# 0          2319    100.00     28.58   17.1735  120
# 1          2388    100.00     38.99   23.3619  120
# 2          2223    100.00     14.83    8.8555  120
# 3          2324    100.00     24.42   14.7832  120
# 4          2212    100.00     10.99    6.4025  120
# ...         ...       ...       ...       ...  ...        ...
# 45913      2212    100.00     10.57    6.2985    4
# 45914      2212    100.00     10.40    6.2741    3
# 45915      2212    100.00     10.37    6.1978    2
# 45916      2223    100.00     14.70    8.6761    1
# 45917      1915     84.93     14.19    8.5120    0
#
# [45918 rows x 28 columns]

# %%
a=train[train['e_id']==e_id[0]]
a['RUL'].plot(xlabel="CYCLE", ylabel="RUL")

# %%
sns.distplot(train['RUL'],kde=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
train.describe().T
# Out:
#                count         mean         std        min          25%  \
# e_id         45918.0   109.396511   62.866193     1.0000    54.000000
# cycle        45918.0   110.307396   68.420545     1.0000    53.000000
# oprsetting1  45918.0    24.008881   14.793676     0.0000    10.004500
# oprsetting2  45918.0     0.571251    0.310935     0.0000     0.250600
# oprsetting3  45918.0    49.172438   32.503659     0.0000    20.000000
# sensor1      45918.0   472.861677   26.460179   445.0000   445.000000
# sensor2      45918.0   579.596770   37.391068   535.6500   549.580000
# sensor3      45918.0  1419.947816  106.286960  1245.4300  1352.910000
# sensor4      45918.0  1205.669194  119.550936  1029.4900  1124.010000
# sensor5      45918.0     8.029878    3.627125     3.9100     3.910000
# sensor6      45918.0    11.596773    5.451857     5.7100     5.720000
# sensor7      45918.0   282.469820  146.539301   136.7500   139.662500
# sensor8      45918.0  2228.406355  145.582047  1914.8500  2211.850000
# sensor9      45918.0  8523.545525  336.780672  7988.7400  8320.740000
# sensor10     45918.0     1.094971    0.127832     0.9300     1.020000
# sensor11     45918.0    42.991879    3.243475    36.2100    41.930000
# sensor12     45918.0   265.943344  138.163656   129.2400   131.360000
# sensor13     45918.0  2334.185381  128.426495  2027.7200  2387.880000
# sensor14     45918.0  8065.548831   84.964099  7851.5900  8061.230000
# sensor15     45918.0     9.332433    0.751834     8.3253     8.676925
# sensor16     45918.0     0.023354    0.004722     0.0200     0.020000
# sensor17     45918.0   348.293915   27.837602   303.0000   331.000000
# sensor18     45918.0  2228.342654  145.693883  1915.0000  2212.000000
# sensor19     45918.0    97.741699    5.378969    84.9300   100.000000
# sensor20     45918.0    20.776822    9.903697    10.2300    10.840000
# sensor21     45918.0    12.466282    5.941954     6.1266     6.504600
# RUL          45918.0    85.532471   39.760726     0.0000    52.000000
#
#                    50%        75%        max
# e_id          110.0000   164.0000   218.0000
# cycle         106.0000   160.0000   357.0000
# oprsetting1    25.0015    41.9981    42.0080
# oprsetting2     0.7000     0.8400     0.8420
# oprsetting3    40.0000    80.0000   100.0000
# sensor1       462.5400   491.1900   518.6700
# sensor2       555.9850   607.3700   644.4300
# sensor3      1369.1400  1499.6975  1614.6600
# sensor4      1138.8700  1307.4375  1442.3600
# sensor5         7.0500    10.5200    14.6200
# sensor6         9.0300    15.4900    21.6100
# sensor7       194.6300   394.1000   555.7200
# sensor8      2223.0500  2323.9600  2388.3600
# sensor9      8359.4350  8777.1700  9216.8300
# sensor10        1.0200     1.2600     1.3000
# sensor11       42.3900    45.3800    48.3900
# sensor12      183.1700   371.2500   523.4600
# sensor13     2388.0700  2388.1600  2390.7400
# sensor14     8081.4750  8126.3800  8274.8800
# sensor15        9.3145     9.3900    11.0826
# sensor16        0.0200     0.0300     0.0300
# sensor17      335.0000   369.0000   398.0000
# sensor18     2223.0000  2324.0000  2388.0000
# sensor19      100.0000   100.0000   100.0000
# sensor20       14.8700    28.4700    39.3300
# sensor21        8.9252    17.0842    23.5905
# RUL           105.0000   120.0000   120.0000

# %%
train=train.drop([ 'sensor10', 'sensor15', 'sensor16',  'oprsetting2'], axis=1)

# %%
train
# Out:
#        e_id  cycle  oprsetting1  oprsetting3  sensor1  sensor2  sensor3  \
# 0         1      1      10.0047         20.0   489.05   604.13  1499.45
# 1         1      2       0.0015        100.0   518.67   642.13  1584.55
# 2         1      3      34.9986         60.0   449.44   555.42  1368.17
# 3         1      4      20.0031          0.0   491.19   607.03  1488.44
# 4         1      5      42.0041         40.0   445.00   549.52  1354.48
# ...     ...    ...          ...          ...      ...      ...      ...
# 45913   218    129      42.0066         40.0   445.00   551.02  1365.27
# 45914   218    130      42.0029         40.0   445.00   550.07  1365.55
# 45915   218    131      41.9999         40.0   445.00   549.92  1359.21
# 45916   218    132      35.0007         60.0   449.44   556.55  1380.05
# 45917   218    133      25.0071         80.0   462.54   537.46  1274.65
#
#        sensor4  sensor5  sensor6  ...  sensor12  sensor13  sensor14  sensor17  \
# 0      1309.95    10.52    15.49  ...    372.15   2388.13   8120.83       368
# 1      1403.96    14.62    21.61  ...    521.81   2388.15   8132.87       391
# 2      1122.49     5.48     8.00  ...    183.26   2387.95   8063.84       334
# 3      1249.18     9.35    13.65  ...    314.84   2388.07   8052.30       364
# 4      1124.32     3.91     5.71  ...    130.44   2387.89   8083.67       330
# ...        ...      ...      ...  ...       ...       ...       ...       ...
# 45913  1147.43     3.91     5.72  ...    130.21   2387.39   8062.87       333
# 45914  1142.21     3.91     5.71  ...    130.24   2387.28   8062.05       332
# 45915  1150.15     3.91     5.72  ...    129.86   2387.33   8062.73       334
# 45916  1145.49     5.48     8.00  ...    182.03   2387.56   8043.21       337
# 45917  1068.77     7.05     9.03  ...    164.18   2027.75   7859.24       310
#
#        sensor18  sensor19  sensor20  sensor21  RUL  MAX_CYCLE
# 0          2319    100.00     28.58   17.1735  120
# 1          2388    100.00     38.99   23.3619  120
# 2          2223    100.00     14.83    8.8555  120
# 3          2324    100.00     24.42   14.7832  120
# 4          2212    100.00     10.99    6.4025  120
# ...         ...       ...       ...       ...  ...        ...
# 45913      2212    100.00     10.57    6.2985    4
# 45914      2212    100.00     10.40    6.2741    3
# 45915      2212    100.00     10.37    6.1978    2
# 45916      2223    100.00     14.70    8.6761    1
# 45917      1915     84.93     14.19    8.5120    0
#
# [45918 rows x 24 columns]

# %%
train.hist(bins=50, figsize=(18,16))
plt.show()

# %%
values = train[train.e_id==1].values
groups = [5, 6, 7, 8, 9, 10, 11,12,13]
i = 1
plt.figure(figsize=(10,20))
for group in groups:
 plt.subplot(len(groups), 1, i)
 plt.plot(values[:, group])
 plt.title(train.columns[group], y=0.5, loc='right')
 i += 1
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
ntrain = train.copy()

# %%
ntrain.iloc[:,2:23] = scaler.fit_transform(ntrain.iloc[:,2:23])

# %%
ntrain.describe().T
# Out:
#                count        mean        std  min        25%         50%  \
# e_id         45918.0  109.396511  62.866193  1.0  54.000000  110.000000
# cycle        45918.0  110.307396  68.420545  1.0  53.000000  106.000000
# oprsetting1  45918.0    0.571531   0.352163  0.0   0.238157    0.595160
# oprsetting3  45918.0    0.491724   0.325037  0.0   0.200000    0.400000
# sensor1      45918.0    0.378196   0.359172  0.0   0.000000    0.238089
# sensor2      45918.0    0.403997   0.343731  0.0   0.128057    0.186937
# sensor3      45918.0    0.472653   0.287861  0.0   0.291092    0.335049
# sensor4      45918.0    0.426718   0.289561  0.0   0.228934    0.264926
# sensor5      45918.0    0.384676   0.338667  0.0   0.000000    0.293184
# sensor6      45918.0    0.370237   0.342884  0.0   0.000629    0.208805
# sensor7      45918.0    0.347805   0.349761  0.0   0.006952    0.138148
# sensor8      45918.0    0.662196   0.307453  0.0   0.627231    0.650884
# sensor9      45918.0    0.435477   0.274231  0.0   0.270338    0.301847
# sensor11     45918.0    0.556805   0.266295  0.0   0.469622    0.507389
# sensor12     45918.0    0.346769   0.350473  0.0   0.005378    0.136802
# sensor13     45918.0    0.844211   0.353773  0.0   0.992122    0.992645
# sensor14     45918.0    0.505466   0.200723  0.0   0.495263    0.543091
# sensor17     45918.0    0.476778   0.293027  0.0   0.294737    0.336842
# sensor18     45918.0    0.662458   0.308021  0.0   0.627907    0.651163
# sensor19     45918.0    0.850146   0.356932  0.0   1.000000    1.000000
# sensor20     45918.0    0.362434   0.340333  0.0   0.020962    0.159450
# sensor21     45918.0    0.363016   0.340242  0.0   0.021645    0.160251
# RUL          45918.0    0.712771   0.331339  0.0   0.433333    0.875000
#
#                     75%    max
# e_id         164.000000  218.0
# cycle        160.000000  357.0
# oprsetting1    0.999764    1.0
# oprsetting3    0.800000    1.0
# sensor1        0.626985    1.0
# sensor2        0.659312    1.0
# sensor3        0.688643    1.0
# sensor4        0.673208    1.0
# sensor5        0.617180    1.0
# sensor6        0.615094    1.0
# sensor7        0.614244    1.0
# sensor8        0.863994    1.0
# sensor9        0.641997    1.0
# sensor11       0.752874    1.0
# sensor12       0.613896    1.0
# sensor13       0.992893    1.0
# sensor14       0.649177    1.0
# sensor17       0.694737    1.0
# sensor18       0.864693    1.0
# sensor19       1.000000    1.0
# sensor20       0.626804    1.0
# sensor21       0.627443    1.0
# RUL            1.000000    1.0

# %%
ntest.iloc[:,2:22] = scaler.fit_transform(ntest.iloc[:,2:22])

# %%
ntest.describe().T
# Out:
#                count        mean         std  min         25%         50%  \
# e_id         55156.0  221.334488  124.539458  1.0  116.000000  223.000000
# cycle        55156.0   77.962035   55.441894  1.0   32.000000   68.000000
# oprsetting1  55156.0    0.571454    0.351715  0.0    0.238157    0.595158
# oprsetting3  55156.0    0.490790    0.325032  0.0    0.200000    0.400000
# sensor1      55156.0    0.378179    0.358613  0.0    0.000000    0.238089
# sensor2      55156.0    0.404526    0.343892  0.0    0.128581    0.186884
# sensor3      55156.0    0.476295    0.292942  0.0    0.292592    0.335598
# sensor4      55156.0    0.431781    0.296374  0.0    0.231962    0.260724
# sensor5      55156.0    0.384574    0.338089  0.0    0.000000    0.293184
# sensor6      55156.0    0.370042    0.342321  0.0    0.000629    0.208805
# sensor7      55156.0    0.347183    0.349590  0.0    0.006137    0.137488
# sensor8      55156.0    0.661725    0.307790  0.0    0.627194    0.650789
# sensor9      55156.0    0.445324    0.281641  0.0    0.277714    0.307118
# sensor11     55156.0    0.557537    0.268624  0.0    0.472591    0.502492
# sensor12     55156.0    0.346514    0.350285  0.0    0.004948    0.136527
# sensor13     55156.0    0.845098    0.354997  0.0    0.993927    0.994396
# sensor14     55156.0    0.532552    0.216191  0.0    0.528159    0.576204
# sensor17     55156.0    0.471502    0.292448  0.0    0.284211    0.326316
# sensor18     55156.0    0.662097    0.308286  0.0    0.627907    0.651163
# sensor19     55156.0    0.849645    0.357423  0.0    1.000000    1.000000
# sensor20     55156.0    0.361955    0.339668  0.0    0.020919    0.159122
# sensor21     55156.0    0.365410    0.339541  0.0    0.024276    0.162786
#
#                     75%    max
# e_id         329.000000  435.0
# cycle        115.000000  298.0
# oprsetting1    0.999764    1.0
# oprsetting3    0.800000    1.0
# sensor1        0.626985    1.0
# sensor2        0.660772    1.0
# sensor3        0.697575    1.0
# sensor4        0.687376    1.0
# sensor5        0.617180    1.0
# sensor6        0.615094    1.0
# sensor7        0.614088    1.0
# sensor8        0.863966    1.0
# sensor9        0.660169    1.0
# sensor11       0.758306    1.0
# sensor12       0.614145    1.0
# sensor13       0.994617    1.0
# sensor14       0.692622    1.0
# sensor17       0.694737    1.0
# sensor18       0.864693    1.0
# sensor19       1.000000    1.0
# sensor20       0.626543    1.0
# sensor21       0.629859    1.0

# %%
pd.DataFrame(ntrain.columns).T
# Out:
#      0      1            2            3        4        5        6        7   \
# 0  e_id  cycle  oprsetting1  oprsetting3  sensor1  sensor2  sensor3  sensor4
#
#         8        9   ...        14        15        16        17        18  \
# 0  sensor5  sensor6  ...  sensor12  sensor13  sensor14  sensor17  sensor18
#
#          19        20        21   22         23
# 0  sensor19  sensor20  sensor21  RUL  MAX_CYCLE
#
# [1 rows x 24 columns]

# %%
sns.distplot(ntrain['RUL'],kde=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
a=ntrain[ntrain['e_id']==e_id[0]]
a['RUL'].plot(xlabel="CYCLE", ylabel="RUL")

# %%
#splitting of data based on the engin id 70% train and 30% validation
trn = ntrain[ntrain['e_id'] < 154]
val = ntrain[ntrain['e_id'] >=154]

# %%
trn.head()
# Out:
#    e_id  cycle  oprsetting1  oprsetting3   sensor1   sensor2   sensor3  \
# 0     1      1     0.238162          0.2  0.597937  0.629527  0.687972
# 1     1      2     0.000036          1.0  1.000000  0.978856  0.918452
# 2     1      3     0.833141          0.6  0.060269  0.181743  0.332422
# 3     1      4     0.476174          0.0  0.626985  0.656187  0.658153
# 4     1      5     0.999907          0.4  0.000000  0.127505  0.295344
#
#     sensor4   sensor5   sensor6  ...  sensor12  sensor13  sensor14  sensor17  \
# 0  0.679294  0.617180  0.615094  ...  0.616179  0.992810  0.636065  0.684211
# 1  0.906993  1.000000  1.000000  ...  0.995815  0.992865  0.664509  0.926316
# 2  0.225253  0.146592  0.144025  ...  0.137030  0.992314  0.501429  0.326316
# 3  0.532105  0.507937  0.499371  ...  0.470803  0.992645  0.474167  0.642105
# 4  0.229685  0.000000  0.000000  ...  0.003044  0.992149  0.548277  0.284211
#
#    sensor18  sensor19  sensor20  sensor21  RUL  MAX_CYCLE
# 0  0.854123       1.0  0.630584  0.632556  1.0
# 1  1.000000       1.0  0.988316  0.986910  1.0
# 2  0.651163       1.0  0.158076  0.156259  1.0
# 3  0.864693       1.0  0.487629  0.495685  1.0
# 4  0.627907       1.0  0.026117  0.015798  1.0
#
# [5 rows x 24 columns]

# %%
trn.tail()
# Out:
#        e_id  cycle  oprsetting1  oprsetting3   sensor1   sensor2   sensor3  \
# 32399   153    273     0.999964          0.4  0.000000  0.136146  0.317471
# 32400   153    274     0.595170          0.8  0.238089  0.015076  0.063375
# 32401   153    275     0.595287          0.8  0.238089  0.020132  0.084013
# 32402   153    276     0.833363          0.6  0.060269  0.194613  0.372288
# 32403   153    277     0.999876          0.4  0.000000  0.136698  0.321859
#
#         sensor4   sensor5   sensor6  ...  sensor12  sensor13  sensor14  \
# 32399  0.290116  0.000000  0.000629  ...  0.002993  0.991764  0.536701
# 32400  0.066922  0.293184  0.208805  ...  0.087819  0.001322  0.055872
# 32401  0.095090  0.293184  0.208805  ...  0.088047  0.001350  0.052470
# 32402  0.280573  0.146592  0.144025  ...  0.134975  0.992397  0.502941
# 32403  0.280330  0.000000  0.000629  ...  0.000939  0.991984  0.543693
#
#        sensor17  sensor18  sensor19  sensor20  sensor21       RUL  MAX_CYCLE
# 32399  0.315789  0.627907       1.0  0.005155  0.006075  0.033333
# 32400  0.084211  0.000000       0.0  0.126804  0.133424  0.025000
# 32401  0.084211  0.000000       0.0  0.141581  0.138720  0.016667
# 32402  0.357895  0.651163       1.0  0.149828  0.148392  0.008333
# 32403  0.315789  0.627907       1.0  0.002405  0.011143  0.000000
#
# [5 rows x 24 columns]

# %%
val.head()
# Out:
#        e_id  cycle  oprsetting1  oprsetting3   sensor1   sensor2   sensor3  \
# 32404   154      1     0.999855          0.4  0.000000  0.121622  0.273055
# 32405   154      2     0.000002          1.0  1.000000  0.978213  0.943856
# 32406   154      3     0.999957          0.4  0.000000  0.126310  0.287544
# 32407   154      4     0.833258          0.6  0.060269  0.178158  0.324513
# 32408   154      5     0.000017          1.0  1.000000  0.975731  0.912791
#
#         sensor4   sensor5   sensor6  ...  sensor12  sensor13  sensor14  \
# 32404  0.195316  0.000000  0.000629  ...  0.003019  0.992783  0.554348
# 32405  0.895972  1.000000  0.999371  ...  0.997616  0.992535  0.683409
# 32406  0.232180  0.000000  0.000000  ...  0.003475  0.992452  0.547969
# 32407  0.218059  0.146592  0.144025  ...  0.137334  0.992480  0.507265
# 32408  0.867028  1.000000  1.000000  ...  0.997793  0.992204  0.668100
#
#        sensor17  sensor18  sensor19  sensor20  sensor21  RUL  MAX_CYCLE
# 32404  0.273684  0.627907       1.0  0.013402  0.010187  1.0
# 32405  0.936842  1.000000       1.0  0.990034  0.989092  1.0
# 32406  0.284211  0.627907       1.0  0.011684  0.023019  1.0
# 32407  0.305263  0.651163       1.0  0.161512  0.160680  1.0
# 32408  0.915789  1.000000       1.0  0.985911  0.996507  1.0
#
# [5 rows x 24 columns]

# %%
val.tail()
# Out:
#        e_id  cycle  oprsetting1  oprsetting3   sensor1   sensor2   sensor3  \
# 45913   218    129     0.999967          0.4  0.000000  0.141294  0.324567
# 45914   218    130     0.999879          0.4  0.000000  0.132561  0.325326
# 45915   218    131     0.999807          0.4  0.000000  0.131182  0.308155
# 45916   218    132     0.833191          0.6  0.060269  0.192131  0.364597
# 45917   218    133     0.595294          0.8  0.238089  0.016639  0.079138
#
#         sensor4   sensor5   sensor6  ...  sensor12  sensor13  sensor14  \
# 45913  0.285659  0.000000  0.000629  ...  0.002461  0.990772  0.499138
# 45914  0.273016  0.000000  0.000000  ...  0.002537  0.990469  0.497201
# 45915  0.292247  0.000000  0.000629  ...  0.001573  0.990607  0.498807
# 45916  0.280960  0.146592  0.144025  ...  0.133910  0.991240  0.452692
# 45917  0.095139  0.293184  0.208805  ...  0.088631  0.000083  0.018073
#
#        sensor17  sensor18  sensor19  sensor20  sensor21       RUL  MAX_CYCLE
# 45913  0.315789  0.627907       1.0  0.011684  0.009843  0.033333
# 45914  0.305263  0.627907       1.0  0.005842  0.008446  0.025000
# 45915  0.326316  0.627907       1.0  0.004811  0.004077  0.016667
# 45916  0.357895  0.651163       1.0  0.153608  0.145987  0.008333
# 45917  0.073684  0.000000       0.0  0.136082  0.136590  0.000000
#
# [5 rows x 24 columns]

# %%
X_train = trn.loc[:, trn.columns != 'RUL']
y_train = trn['RUL']
X_test = val.loc[:, val.columns != 'RUL']
y_test = val['RUL']

# %%
X_train
# Out:
#        e_id  cycle  oprsetting1  oprsetting3   sensor1   sensor2   sensor3  \
# 0         1      1     0.238162          0.2  0.597937  0.629527  0.687972
# 1         1      2     0.000036          1.0  1.000000  0.978856  0.918452
# 2         1      3     0.833141          0.6  0.060269  0.181743  0.332422
# 3         1      4     0.476174          0.0  0.626985  0.656187  0.658153
# 4         1      5     0.999907          0.4  0.000000  0.127505  0.295344
# ...     ...    ...          ...          ...       ...       ...       ...
# 32399   153    273     0.999964          0.4  0.000000  0.136146  0.317471
# 32400   153    274     0.595170          0.8  0.238089  0.015076  0.063375
# 32401   153    275     0.595287          0.8  0.238089  0.020132  0.084013
# 32402   153    276     0.833363          0.6  0.060269  0.194613  0.372288
# 32403   153    277     0.999876          0.4  0.000000  0.136698  0.321859
#
#         sensor4   sensor5   sensor6  ...  sensor11  sensor12  sensor13  \
# 0      0.679294  0.617180  0.615094  ...  0.754516  0.616179  0.992810
# 1      0.906993  1.000000  1.000000  ...  0.909688  0.995815  0.992865
# 2      0.225253  0.146592  0.144025  ...  0.468801  0.137030  0.992314
# 3      0.532105  0.507937  0.499371  ...  0.660920  0.470803  0.992645
# 4      0.229685  0.000000  0.000000  ...  0.458128  0.003044  0.992149
# ...         ...       ...       ...  ...       ...       ...       ...
# 32399  0.290116  0.000000  0.000629  ...  0.532020  0.002993  0.991764
# 32400  0.066922  0.293184  0.208805  ...  0.070608  0.087819  0.001322
# 32401  0.095090  0.293184  0.208805  ...  0.077997  0.088047  0.001350
# 32402  0.280573  0.146592  0.144025  ...  0.513957  0.134975  0.992397
# 32403  0.280330  0.000000  0.000629  ...  0.532020  0.000939  0.991984
#
#        sensor14  sensor17  sensor18  sensor19  sensor20  sensor21  MAX_CYCLE
# 0      0.636065  0.684211  0.854123       1.0  0.630584  0.632556
# 1      0.664509  0.926316  1.000000       1.0  0.988316  0.986910
# 2      0.501429  0.326316  0.651163       1.0  0.158076  0.156259
# 3      0.474167  0.642105  0.864693       1.0  0.487629  0.495685
# 4      0.548277  0.284211  0.627907       1.0  0.026117  0.015798
# ...         ...       ...       ...       ...       ...       ...        ...
# 32399  0.536701  0.315789  0.627907       1.0  0.005155  0.006075
# 32400  0.055872  0.084211  0.000000       0.0  0.126804  0.133424
# 32401  0.052470  0.084211  0.000000       0.0  0.141581  0.138720
# 32402  0.502941  0.357895  0.651163       1.0  0.149828  0.148392
# 32403  0.543693  0.315789  0.627907       1.0  0.002405  0.011143
#
# [32404 rows x 23 columns]

# %%
cpy = X_test.copy()

# %%
X_train = X_train.drop(['e_id','cycle','MAX_CYCLE'],axis=1)
X_test = X_test.drop(['e_id','cycle','MAX_CYCLE'],axis=1)

# %%
ntest_cpy = ntest

# %%
ntest_cpy = ntest_cpy.drop(['e_id','cycle'],axis = 1)

# %%
ntest_cpy = ntest_cpy.to_numpy()

# %%
X_train = X_train.to_numpy()
X_test = X_test.to_numpy()
y_train= y_train.to_numpy()
y_test = y_test.to_numpy()

# %%
cpy = cpy.to_numpy()

# %% [markdown]
# # Linear Regression

# %%
from sklearn import datasets, linear_model, metrics
reg = linear_model.LinearRegression()

# %%
from sklearn.feature_selection import RFE
rfe = RFE(reg)

# %%
fit = rfe.fit(X_train, y_train)

# %%
print("Num Features: %d" % fit.n_features_)
print("Selected Features: %s" % fit.support_)
print("Feature Ranking: %s" % fit.ranking_)
# Out:
# Num Features: 10
# Selected Features: [False False  True  True False False  True  True  True  True  True  True
#   True False False False  True False False False]
# Feature Ranking: [ 4  8  1  1  9  5  1  1  1  1  1  1  1  2 11  6  1  3 10  7]

# %%
y_pre = fit.predict(X_test)

# %%
y_pre
# Out:
# array([1.0190238 , 1.20831249, 1.10227364, ..., 0.23605028, 0.27166202,
#        0.24403624])

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_error as mae
R2_score = r2_score(y_test,y_pre)
MSE = mean_squared_error(y_test,y_pre)
from math import sqrt
RMSE=sqrt(mean_squared_error(y_test,y_pre))
MAE = mae(y_test,y_pre)
print("R2_Score:",R2_score)
print("MSE:",MSE)
print("RMSE:",RMSE)
print("MAE:",MAE)
# Out:
# R2_Score: 0.6689369465039579
# MSE: 0.036458932714344534
# RMSE: 0.19094222349795903
# MAE: 0.1555811505127454

# %%
fig = plt.figure(figsize=(18,10))
plt.plot(y_pre,c='red',label='prediction')
plt.plot(y_test,c='blue',label='y_test')
plt.legend()
plt.show()

# %%
ncpy=pd.DataFrame(cpy,columns=['e_id','cycle','oprsetting1','oprsetting3','sensor1','sensor2','sensor3','sensor4','sensor5','sensor6','sensor7','sensor8','sensor9','sensor11','sensor12','sensor13','sensor14','sensor17','sensor18','sensor19','sensor20','sensor21','MAX_CYCLE'])
ncpy['y_test']=pd.DataFrame(y_test)
ncpy['y_pre']=pd.DataFrame(y_pre)

# %%
ncpy
# Out:
#       e_id cycle oprsetting1 oprsetting3   sensor1   sensor2   sensor3  \
# 0      154     1    0.999855         0.4       0.0  0.121622  0.273055
# 1      154     2    0.000002         1.0       1.0  0.978213  0.943856
# 2      154     3    0.999957         0.4       0.0   0.12631  0.287544
# 3      154     4    0.833258         0.6  0.060269  0.178158  0.324513
# 4      154     5    0.000017         1.0       1.0  0.975731  0.912791
# ...    ...   ...         ...         ...       ...       ...       ...
# 13509  218   129    0.999967         0.4       0.0  0.141294  0.324567
# 13510  218   130    0.999879         0.4       0.0  0.132561  0.325326
# 13511  218   131    0.999807         0.4       0.0  0.131182  0.308155
# 13512  218   132    0.833191         0.6  0.060269  0.192131  0.364597
# 13513  218   133    0.595294         0.8  0.238089  0.016639  0.079138
#
#         sensor4   sensor5   sensor6  ...  sensor13  sensor14  sensor17  \
# 0      0.195316       0.0  0.000629  ...  0.992783  0.554348  0.273684
# 1      0.895972       1.0  0.999371  ...  0.992535  0.683409  0.936842
# 2       0.23218       0.0       0.0  ...  0.992452  0.547969  0.284211
# 3      0.218059  0.146592  0.144025  ...   0.99248  0.507265  0.305263
# 4      0.867028       1.0       1.0  ...  0.992204    0.6681  0.915789
# ...         ...       ...       ...  ...       ...       ...       ...
# 13509  0.285659       0.0  0.000629  ...  0.990772  0.499138  0.315789
# 13510  0.273016       0.0       0.0  ...  0.990469  0.497201  0.305263
# 13511  0.292247       0.0  0.000629  ...  0.990607  0.498807  0.326316
# 13512   0.28096  0.146592  0.144025  ...   0.99124  0.452692  0.357895
# 13513  0.095139  0.293184  0.208805  ...  0.000083  0.018073  0.073684
#
#        sensor18 sensor19  sensor20  sensor21 MAX_CYCLE    y_test     y_pre
# 0      0.627907      1.0  0.013402  0.010187            1.000000  1.019024
# 1           1.0      1.0  0.990034  0.989092            1.000000  1.208312
# 2      0.627907      1.0  0.011684  0.023019            1.000000  1.102274
# 3      0.651163      1.0  0.161512   0.16068            1.000000  1.153554
# 4           1.0      1.0  0.985911  0.996507            1.000000  1.414118
# ...         ...      ...       ...       ...       ...       ...       ...
# 13509  0.627907      1.0  0.011684  0.009843            0.033333  0.274675
# 13510  0.627907      1.0  0.005842  0.008446            0.025000  0.440399
# 13511  0.627907      1.0  0.004811  0.004077            0.016667  0.236050
# 13512  0.651163      1.0  0.153608  0.145987            0.008333  0.271662
# 13513       0.0      0.0  0.136082   0.13659            0.000000  0.244036
#
# [13514 rows x 25 columns]

# %%
#a=ncpy[ncpy['e_id']==154]
#a['y_test'].plot(xlabel="CYCLE", ylabel="RUL",color='blue')
#a['y_pre'].plot(xlabel="CYCLE", ylabel="RUL",color='red')

# %%
a=ncpy[ncpy['e_id']==154]
plt.plot(a['cycle'],a['y_test'],color='blue')
plt.plot(a['cycle'],a['y_pre'],color='red')
plt.xlabel('CYCLE')
plt.ylabel('RUL') 
plt.title('compare')
plt.legend() 
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
Test_yprd = fit.predict(ntest_cpy)

# %%
ntest['test_rul']=pd.DataFrame(Test_yprd)

# %%
fig = plt.figure(figsize=(30,10))
plt.plot(Test_yprd,c='red',label='prediction')
plt.legend()
plt.show()

# %%
a=ntest[ntest['e_id']==5]
plt.plot(a['cycle'],a['test_rul'],color='red')
plt.xlabel('CYCLE')
plt.ylabel('RUL') 
plt.legend() 
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVR
svr = SVR(kernel = 'rbf')

# %%
from sklearn.feature_selection import RFE
rfe = RFE(svr)

# %%
svr.fit(X_train, y_train)
# Out:
# SVR()

# %%
print("Num Features: %d" % fit.n_features_)
print("Selected Features: %s" % fit.support_)
print("Feature Ranking: %s" % fit.ranking_)
# Out:
# Num Features: 10
# Selected Features: [False False  True  True False False  True  True  True  True  True  True
#   True False False False  True False False False]
# Feature Ranking: [ 4  8  1  1  9  5  1  1  1  1  1  1  1  2 11  6  1  3 10  7]

# %%
y_pre = svr.predict(X_test)

# %%
y_pre
# Out:
# array([1.19038867, 1.00832791, 1.05474138, ..., 0.08270677, 0.14558312,
#        0.07636466])

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_error as mae
R2_score = r2_score(y_test,y_pre)
MSE = mean_squared_error(y_test,y_pre)
from math import sqrt
RMSE=sqrt(mean_squared_error(y_test,y_pre))
MAE = mae(y_test,y_pre)
print("R2_Score:",R2_score)
print("MSE:",MSE)
print("RMSE:",RMSE)
print("MAE:",MAE)
# Out:
# R2_Score: 0.6999361699190959
# MSE: 0.03304508574847353
# RMSE: 0.18178307332772634
# MAE: 0.14671670438356366

# %%
fig = plt.figure(figsize=(12,10))
plt.plot(y_pre,c='red',label='prediction')
plt.plot(y_test,c='blue',label='y_test')
plt.legend()
plt.show()

# %%
ncpy=pd.DataFrame(cpy,columns=['e_id','cycle','oprsetting1','oprsetting3','sensor1','sensor2','sensor3','sensor4','sensor5','sensor6','sensor7','sensor8','sensor9','sensor11','sensor12','sensor13','sensor14','sensor17','sensor18','sensor19','sensor20','sensor21','MAX_CYCLE'])
ncpy['y_test']=pd.DataFrame(y_test)
ncpy['y_pre']=pd.DataFrame(y_pre)

# %%
ncpy
# Out:
#       e_id cycle oprsetting1 oprsetting3   sensor1   sensor2   sensor3  \
# 0      154     1    0.999855         0.4       0.0  0.121622  0.273055
# 1      154     2    0.000002         1.0       1.0  0.978213  0.943856
# 2      154     3    0.999957         0.4       0.0   0.12631  0.287544
# 3      154     4    0.833258         0.6  0.060269  0.178158  0.324513
# 4      154     5    0.000017         1.0       1.0  0.975731  0.912791
# ...    ...   ...         ...         ...       ...       ...       ...
# 13509  218   129    0.999967         0.4       0.0  0.141294  0.324567
# 13510  218   130    0.999879         0.4       0.0  0.132561  0.325326
# 13511  218   131    0.999807         0.4       0.0  0.131182  0.308155
# 13512  218   132    0.833191         0.6  0.060269  0.192131  0.364597
# 13513  218   133    0.595294         0.8  0.238089  0.016639  0.079138
#
#         sensor4   sensor5   sensor6  ...  sensor13  sensor14  sensor17  \
# 0      0.195316       0.0  0.000629  ...  0.992783  0.554348  0.273684
# 1      0.895972       1.0  0.999371  ...  0.992535  0.683409  0.936842
# 2       0.23218       0.0       0.0  ...  0.992452  0.547969  0.284211
# 3      0.218059  0.146592  0.144025  ...   0.99248  0.507265  0.305263
# 4      0.867028       1.0       1.0  ...  0.992204    0.6681  0.915789
# ...         ...       ...       ...  ...       ...       ...       ...
# 13509  0.285659       0.0  0.000629  ...  0.990772  0.499138  0.315789
# 13510  0.273016       0.0       0.0  ...  0.990469  0.497201  0.305263
# 13511  0.292247       0.0  0.000629  ...  0.990607  0.498807  0.326316
# 13512   0.28096  0.146592  0.144025  ...   0.99124  0.452692  0.357895
# 13513  0.095139  0.293184  0.208805  ...  0.000083  0.018073  0.073684
#
#        sensor18 sensor19  sensor20  sensor21 MAX_CYCLE    y_test     y_pre
# 0      0.627907      1.0  0.013402  0.010187            1.000000  1.190389
# 1           1.0      1.0  0.990034  0.989092            1.000000  1.008328
# 2      0.627907      1.0  0.011684  0.023019            1.000000  1.054741
# 3      0.651163      1.0  0.161512   0.16068            1.000000  1.188312
# 4           1.0      1.0  0.985911  0.996507            1.000000  1.339434
# ...         ...      ...       ...       ...       ...       ...       ...
# 13509  0.627907      1.0  0.011684  0.009843            0.033333  0.175964
# 13510  0.627907      1.0  0.005842  0.008446            0.025000  0.312304
# 13511  0.627907      1.0  0.004811  0.004077            0.016667  0.082707
# 13512  0.651163      1.0  0.153608  0.145987            0.008333  0.145583
# 13513       0.0      0.0  0.136082   0.13659            0.000000  0.076365
#
# [13514 rows x 25 columns]

# %%
a=ncpy[ncpy['e_id']==154]
plt.plot(a['cycle'],a['y_test'],color='blue')
plt.plot(a['cycle'],a['y_pre'],color='red')
plt.xlabel('CYCLE')
plt.ylabel('RUL') 
plt.title('compare')
plt.legend() 
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#fit = rfe.fit(X_train, y_train)

# %%
Test_yprd = fit.predict(ntest_cpy)
ntest['test_rul']=pd.DataFrame(Test_yprd)
fig = plt.figure(figsize=(30,10))
plt.plot(Test_yprd,c='red',label='prediction')
plt.legend()
plt.show()

# %%
a=ntest[ntest['e_id']==5]
plt.plot(a['cycle'],a['test_rul'],color='red')
plt.xlabel('CYCLE')
plt.ylabel('RUL') 
plt.legend() 
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor()

# %%
from sklearn.feature_selection import RFE
rfe = RFE(regressor)

# %%
fit = rfe.fit(X_train, y_train)

# %%
print("Num Features: %d" % fit.n_features_)
print("Selected Features: %s" % fit.support_)
print("Feature Ranking: %s" % fit.ranking_)
# Out:
# Num Features: 10
# Selected Features: [False False False  True  True  True False  True  True False  True  True
#   True  True  True False False False False False]
# Feature Ranking: [ 5  7  8  1  1  1 10  1  1  3  1  1  1  1  1  6  9 11  4  2]

# %%
y_pre = fit.predict(X_test)

# %%
y_pre
# Out:
# array([0.98      , 0.936     , 0.98716667, ..., 0.04258333, 0.06041667,
#        0.0375    ])

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_error as mae
R2_score = r2_score(y_test,y_pre)
MSE = mean_squared_error(y_test,y_pre)
from math import sqrt
RMSE=sqrt(mean_squared_error(y_test,y_pre))
MAE = mae(y_test,y_pre)
print("R2_Score:",R2_score)
print("MSE:",MSE)
print("RMSE:",RMSE)
print("MAE:",MAE)
# Out:
# R2_Score: 0.7688483638251421
# MSE: 0.025456002598642564
# RMSE: 0.1595493735451273
# MAE: 0.11556373020571259

# %%
fig = plt.figure(figsize=(18,10))
plt.plot(y_pre,c='red',label='prediction')
plt.plot(y_test,c='blue',label='y_test')
plt.legend()
plt.show()

# %%
ncpy=pd.DataFrame(cpy,columns=['e_id','cycle','oprsetting1','oprsetting3','sensor1','sensor2','sensor3','sensor4','sensor5','sensor6','sensor7','sensor8','sensor9','sensor11','sensor12','sensor13','sensor14','sensor17','sensor18','sensor19','sensor20','sensor21','MAX_CYCLE'])
ncpy['y_test']=pd.DataFrame(y_test)
ncpy['y_pre']=pd.DataFrame(y_pre)

# %%
ncpy
# Out:
#       e_id cycle oprsetting1 oprsetting3   sensor1   sensor2   sensor3  \
# 0      154     1    0.999855         0.4       0.0  0.121622  0.273055
# 1      154     2    0.000002         1.0       1.0  0.978213  0.943856
# 2      154     3    0.999957         0.4       0.0   0.12631  0.287544
# 3      154     4    0.833258         0.6  0.060269  0.178158  0.324513
# 4      154     5    0.000017         1.0       1.0  0.975731  0.912791
# ...    ...   ...         ...         ...       ...       ...       ...
# 13509  218   129    0.999967         0.4       0.0  0.141294  0.324567
# 13510  218   130    0.999879         0.4       0.0  0.132561  0.325326
# 13511  218   131    0.999807         0.4       0.0  0.131182  0.308155
# 13512  218   132    0.833191         0.6  0.060269  0.192131  0.364597
# 13513  218   133    0.595294         0.8  0.238089  0.016639  0.079138
#
#         sensor4   sensor5   sensor6  ...  sensor13  sensor14  sensor17  \
# 0      0.195316       0.0  0.000629  ...  0.992783  0.554348  0.273684
# 1      0.895972       1.0  0.999371  ...  0.992535  0.683409  0.936842
# 2       0.23218       0.0       0.0  ...  0.992452  0.547969  0.284211
# 3      0.218059  0.146592  0.144025  ...   0.99248  0.507265  0.305263
# 4      0.867028       1.0       1.0  ...  0.992204    0.6681  0.915789
# ...         ...       ...       ...  ...       ...       ...       ...
# 13509  0.285659       0.0  0.000629  ...  0.990772  0.499138  0.315789
# 13510  0.273016       0.0       0.0  ...  0.990469  0.497201  0.305263
# 13511  0.292247       0.0  0.000629  ...  0.990607  0.498807  0.326316
# 13512   0.28096  0.146592  0.144025  ...   0.99124  0.452692  0.357895
# 13513  0.095139  0.293184  0.208805  ...  0.000083  0.018073  0.073684
#
#        sensor18 sensor19  sensor20  sensor21 MAX_CYCLE    y_test     y_pre
# 0      0.627907      1.0  0.013402  0.010187            1.000000  0.980000
# 1           1.0      1.0  0.990034  0.989092            1.000000  0.936000
# 2      0.627907      1.0  0.011684  0.023019            1.000000  0.987167
# 3      0.651163      1.0  0.161512   0.16068            1.000000  0.994417
# 4           1.0      1.0  0.985911  0.996507            1.000000  0.965833
# ...         ...      ...       ...       ...       ...       ...       ...
# 13509  0.627907      1.0  0.011684  0.009843            0.033333  0.033000
# 13510  0.627907      1.0  0.005842  0.008446            0.025000  0.065083
# 13511  0.627907      1.0  0.004811  0.004077            0.016667  0.042583
# 13512  0.651163      1.0  0.153608  0.145987            0.008333  0.060417
# 13513       0.0      0.0  0.136082   0.13659            0.000000  0.037500
#
# [13514 rows x 25 columns]

# %%
a=ncpy[ncpy['e_id']==154]
plt.plot(a['cycle'],a['y_test'],color='blue')
plt.plot(a['cycle'],a['y_pre'],color='red')
plt.xlabel('CYCLE')
plt.ylabel('RUL') 
plt.title('compare')
plt.legend() 
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
Test_yprd = fit.predict(ntest_cpy)
ntest['test_rul']=pd.DataFrame(Test_yprd)
fig = plt.figure(figsize=(30,10))
plt.plot(Test_yprd,c='red',label='prediction')
plt.legend()
plt.show()

# %%
a=ntest[ntest['e_id']==5]
plt.plot(a['cycle'],a['test_rul'],color='red')
plt.xlabel('CYCLE')
plt.ylabel('RUL') 
plt.legend() 
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Gradient Boosting Algorithm

# %%
from sklearn.ensemble import GradientBoostingRegressor
model = GradientBoostingRegressor()

# %%
from sklearn.feature_selection import RFE
rfe = RFE(reg)

# %%
fit = rfe.fit(X_train, y_train)

# %%
print("Num Features: %d" % fit.n_features_)
print("Selected Features: %s" % fit.support_)
print("Feature Ranking: %s" % fit.ranking_)
# Out:
# Num Features: 10
# Selected Features: [False False  True  True False False  True  True  True  True  True  True
#   True False False False  True False False False]
# Feature Ranking: [ 4  8  1  1  9  5  1  1  1  1  1  1  1  2 11  6  1  3 10  7]

# %%
y_pre = fit.predict(X_test)

# %%
y_pre
# Out:
# array([1.0190238 , 1.20831249, 1.10227364, ..., 0.23605028, 0.27166202,
#        0.24403624])

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_error as mae
R2_score = r2_score(y_test,y_pre)
MSE = mean_squared_error(y_test,y_pre)
from math import sqrt
RMSE=sqrt(mean_squared_error(y_test,y_pre))
MAE = mae(y_test,y_pre)
print("R2_Score:",R2_score)
print("MSE:",MSE)
print("RMSE:",RMSE)
print("MAE:",MAE)
# Out:
# R2_Score: 0.6689369465039579
# MSE: 0.036458932714344534
# RMSE: 0.19094222349795903
# MAE: 0.1555811505127454

# %%
fig = plt.figure(figsize=(18,10))
plt.plot(y_pre,c='red',label='prediction')
plt.plot(y_test,c='blue',label='y_test')
plt.legend()
plt.show()

# %%
ncpy=pd.DataFrame(cpy,columns=['e_id','cycle','oprsetting1','oprsetting3','sensor1','sensor2','sensor3','sensor4','sensor5','sensor6','sensor7','sensor8','sensor9','sensor11','sensor12','sensor13','sensor14','sensor17','sensor18','sensor19','sensor20','sensor21','MAX_CYCLE'])
ncpy['y_test']=pd.DataFrame(y_test)
ncpy['y_pre']=pd.DataFrame(y_pre)

# %%
ncpy
# Out:
#       e_id cycle oprsetting1 oprsetting3   sensor1   sensor2   sensor3  \
# 0      154     1    0.999855         0.4       0.0  0.121622  0.273055
# 1      154     2    0.000002         1.0       1.0  0.978213  0.943856
# 2      154     3    0.999957         0.4       0.0   0.12631  0.287544
# 3      154     4    0.833258         0.6  0.060269  0.178158  0.324513
# 4      154     5    0.000017         1.0       1.0  0.975731  0.912791
# ...    ...   ...         ...         ...       ...       ...       ...
# 13509  218   129    0.999967         0.4       0.0  0.141294  0.324567
# 13510  218   130    0.999879         0.4       0.0  0.132561  0.325326
# 13511  218   131    0.999807         0.4       0.0  0.131182  0.308155
# 13512  218   132    0.833191         0.6  0.060269  0.192131  0.364597
# 13513  218   133    0.595294         0.8  0.238089  0.016639  0.079138
#
#         sensor4   sensor5   sensor6  ...  sensor13  sensor14  sensor17  \
# 0      0.195316       0.0  0.000629  ...  0.992783  0.554348  0.273684
# 1      0.895972       1.0  0.999371  ...  0.992535  0.683409  0.936842
# 2       0.23218       0.0       0.0  ...  0.992452  0.547969  0.284211
# 3      0.218059  0.146592  0.144025  ...   0.99248  0.507265  0.305263
# 4      0.867028       1.0       1.0  ...  0.992204    0.6681  0.915789
# ...         ...       ...       ...  ...       ...       ...       ...
# 13509  0.285659       0.0  0.000629  ...  0.990772  0.499138  0.315789
# 13510  0.273016       0.0       0.0  ...  0.990469  0.497201  0.305263
# 13511  0.292247       0.0  0.000629  ...  0.990607  0.498807  0.326316
# 13512   0.28096  0.146592  0.144025  ...   0.99124  0.452692  0.357895
# 13513  0.095139  0.293184  0.208805  ...  0.000083  0.018073  0.073684
#
#        sensor18 sensor19  sensor20  sensor21 MAX_CYCLE    y_test     y_pre
# 0      0.627907      1.0  0.013402  0.010187            1.000000  1.019024
# 1           1.0      1.0  0.990034  0.989092            1.000000  1.208312
# 2      0.627907      1.0  0.011684  0.023019            1.000000  1.102274
# 3      0.651163      1.0  0.161512   0.16068            1.000000  1.153554
# 4           1.0      1.0  0.985911  0.996507            1.000000  1.414118
# ...         ...      ...       ...       ...       ...       ...       ...
# 13509  0.627907      1.0  0.011684  0.009843            0.033333  0.274675
# 13510  0.627907      1.0  0.005842  0.008446            0.025000  0.440399
# 13511  0.627907      1.0  0.004811  0.004077            0.016667  0.236050
# 13512  0.651163      1.0  0.153608  0.145987            0.008333  0.271662
# 13513       0.0      0.0  0.136082   0.13659            0.000000  0.244036
#
# [13514 rows x 25 columns]

# %%
a=ncpy[ncpy['e_id']==154]
plt.plot(a['cycle'],a['y_test'],color='blue')
plt.plot(a['cycle'],a['y_pre'],color='red')
plt.xlabel('CYCLE')
plt.ylabel('RUL') 
plt.title('compare')
plt.legend() 
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
Test_yprd = fit.predict(ntest_cpy)
ntest['test_rul']=pd.DataFrame(Test_yprd)
fig = plt.figure(figsize=(30,10))
plt.plot(Test_yprd,c='red',label='prediction')
plt.legend()
plt.show()

# %%
a=ntest[ntest['e_id']==5]
plt.plot(a['cycle'],a['test_rul'],color='red')
plt.xlabel('CYCLE')
plt.ylabel('RUL') 
plt.legend() 
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # **DECISION TREE**

# %%
from sklearn.tree import DecisionTreeRegressor 
  
# create a regressor object
regressor = DecisionTreeRegressor()

# %%
from sklearn.feature_selection import RFE
rfe = RFE(regressor)

# %%
fit = rfe.fit(X_train, y_train)

# %%
print("Num Features: %d" % fit.n_features_)
print("Selected Features: %s" % fit.support_)
print("Feature Ranking: %s" % fit.ranking_)
# Out:
# Num Features: 10
# Selected Features: [False False False  True  True  True False  True  True False  True  True
#   True  True  True False False False False False]
# Feature Ranking: [ 4  7 10  1  1  1  8  1  1  3  1  1  1  1  1  6  9 11  5  2]

# %%
y_pre = fit.predict(X_test)

# %%
y_pre
# Out:
# array([1.        , 1.        , 1.        , ..., 0.        , 0.14166667,
#        0.01666667])

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_error as mae
R2_score = r2_score(y_test,y_pre)
MSE = mean_squared_error(y_test,y_pre)
from math import sqrt
RMSE=sqrt(mean_squared_error(y_test,y_pre))
MAE = mae(y_test,y_pre)
print("R2_Score:",R2_score)
print("MSE:",MSE)
print("RMSE:",RMSE)
print("MAE:",MAE)
# Out:
# R2_Score: 0.5618550031585854
# MSE: 0.04825153030602009
# RMSE: 0.21966230970746914
# MAE: 0.14199533816782597

# %%
fig = plt.figure(figsize=(18,10))
plt.plot(y_pre,c='red',label='prediction')
plt.plot(y_test,c='blue',label='y_test')
plt.legend()
plt.show()

# %%
ncpy=pd.DataFrame(cpy,columns=['e_id','cycle','oprsetting1','oprsetting3','sensor1','sensor2','sensor3','sensor4','sensor5','sensor6','sensor7','sensor8','sensor9','sensor11','sensor12','sensor13','sensor14','sensor17','sensor18','sensor19','sensor20','sensor21','MAX_CYCLE'])
ncpy['y_test']=pd.DataFrame(y_test)
ncpy['y_pre']=pd.DataFrame(y_pre)

# %%
ncpy
# Out:
#       e_id cycle oprsetting1 oprsetting3   sensor1   sensor2   sensor3  \
# 0      154     1    0.999855         0.4       0.0  0.121622  0.273055
# 1      154     2    0.000002         1.0       1.0  0.978213  0.943856
# 2      154     3    0.999957         0.4       0.0   0.12631  0.287544
# 3      154     4    0.833258         0.6  0.060269  0.178158  0.324513
# 4      154     5    0.000017         1.0       1.0  0.975731  0.912791
# ...    ...   ...         ...         ...       ...       ...       ...
# 13509  218   129    0.999967         0.4       0.0  0.141294  0.324567
# 13510  218   130    0.999879         0.4       0.0  0.132561  0.325326
# 13511  218   131    0.999807         0.4       0.0  0.131182  0.308155
# 13512  218   132    0.833191         0.6  0.060269  0.192131  0.364597
# 13513  218   133    0.595294         0.8  0.238089  0.016639  0.079138
#
#         sensor4   sensor5   sensor6  ...  sensor13  sensor14  sensor17  \
# 0      0.195316       0.0  0.000629  ...  0.992783  0.554348  0.273684
# 1      0.895972       1.0  0.999371  ...  0.992535  0.683409  0.936842
# 2       0.23218       0.0       0.0  ...  0.992452  0.547969  0.284211
# 3      0.218059  0.146592  0.144025  ...   0.99248  0.507265  0.305263
# 4      0.867028       1.0       1.0  ...  0.992204    0.6681  0.915789
# ...         ...       ...       ...  ...       ...       ...       ...
# 13509  0.285659       0.0  0.000629  ...  0.990772  0.499138  0.315789
# 13510  0.273016       0.0       0.0  ...  0.990469  0.497201  0.305263
# 13511  0.292247       0.0  0.000629  ...  0.990607  0.498807  0.326316
# 13512   0.28096  0.146592  0.144025  ...   0.99124  0.452692  0.357895
# 13513  0.095139  0.293184  0.208805  ...  0.000083  0.018073  0.073684
#
#        sensor18 sensor19  sensor20  sensor21 MAX_CYCLE    y_test     y_pre
# 0      0.627907      1.0  0.013402  0.010187            1.000000  1.000000
# 1           1.0      1.0  0.990034  0.989092            1.000000  1.000000
# 2      0.627907      1.0  0.011684  0.023019            1.000000  1.000000
# 3      0.651163      1.0  0.161512   0.16068            1.000000  1.000000
# 4           1.0      1.0  0.985911  0.996507            1.000000  0.866667
# ...         ...      ...       ...       ...       ...       ...       ...
# 13509  0.627907      1.0  0.011684  0.009843            0.033333  0.008333
# 13510  0.627907      1.0  0.005842  0.008446            0.025000  0.016667
# 13511  0.627907      1.0  0.004811  0.004077            0.016667  0.000000
# 13512  0.651163      1.0  0.153608  0.145987            0.008333  0.141667
# 13513       0.0      0.0  0.136082   0.13659            0.000000  0.016667
#
# [13514 rows x 25 columns]

# %%
a=ncpy[ncpy['e_id']==154]
plt.plot(a['cycle'],a['y_test'],color='blue')
plt.plot(a['cycle'],a['y_pre'],color='red')
plt.xlabel('CYCLE')
plt.ylabel('RUL') 
plt.title('compare')
plt.legend() 
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
Test_yprd = fit.predict(ntest_cpy)
ntest['test_rul']=pd.DataFrame(Test_yprd)
fig = plt.figure(figsize=(30,10))
plt.plot(Test_yprd,c='red',label='prediction')
plt.legend()
plt.show()

# %%
a=ntest[ntest['e_id']==5]
plt.plot(a['cycle'],a['test_rul'],color='red')
plt.xlabel('CYCLE')
plt.ylabel('RUL') 
plt.legend() 
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # **K NEAREST NEIGHBOURS**

# %%
from sklearn import neighbors

# %% [markdown]
# Implementing the k nearest neighbours

# %%
for K in range(20):
    K = K+1
    model = neighbors.KNeighborsRegressor(n_neighbors = K)

# %%
from sklearn.feature_selection import RFE
rfe = RFE(regressor)

# %% [markdown]
# Fitting the model on selected features

# %%
fit = rfe.fit(X_train, y_train)

# %%
print("Num Features: %d" % fit.n_features_)
print("Selected Features: %s" % fit.support_)
print("Feature Ranking: %s" % fit.ranking_)
# Out:
# Num Features: 10
# Selected Features: [False False False  True  True  True False  True  True False  True  True
#   True  True  True False False False False False]
# Feature Ranking: [ 4  7  9  1  1  1  8  1  1  3  1  1  1  1  1  6 10 11  5  2]

# %%
y_pre = fit.predict(X_test)

# %%
y_pre
# Out:
# array([1.        , 1.        , 1.        , ..., 0.01666667, 0.14166667,
#        0.01666667])

# %% [markdown]
# Calculating the errors

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_error as mae
R2_score = r2_score(y_test,y_pre)
MSE = mean_squared_error(y_test,y_pre)
from math import sqrt
RMSE=sqrt(mean_squared_error(y_test,y_pre))
MAE = mae(y_test,y_pre)
print("R2_Score:",R2_score)
print("MSE:",MSE)
print("RMSE:",RMSE)
print("MAE:",MAE)
# Out:
# R2_Score: 0.5647539999304916
# MSE: 0.04793227291039744
# RMSE: 0.2189344032133768
# MAE: 0.1415402545508362

# %%
fig = plt.figure(figsize=(18,10))
plt.plot(y_pre,c='red',label='prediction')
plt.plot(y_test,c='blue',label='y_test')
plt.legend()
plt.show()

# %%
ncpy=pd.DataFrame(cpy,columns=['e_id','cycle','oprsetting1','oprsetting3','sensor1','sensor2','sensor3','sensor4','sensor5','sensor6','sensor7','sensor8','sensor9','sensor11','sensor12','sensor13','sensor14','sensor17','sensor18','sensor19','sensor20','sensor21','MAX_CYCLE'])
ncpy['y_test']=pd.DataFrame(y_test)
ncpy['y_pre']=pd.DataFrame(y_pre)

# %%
ncpy
# Out:
#       e_id cycle oprsetting1 oprsetting3   sensor1   sensor2   sensor3  \
# 0      154     1    0.999855         0.4       0.0  0.121622  0.273055
# 1      154     2    0.000002         1.0       1.0  0.978213  0.943856
# 2      154     3    0.999957         0.4       0.0   0.12631  0.287544
# 3      154     4    0.833258         0.6  0.060269  0.178158  0.324513
# 4      154     5    0.000017         1.0       1.0  0.975731  0.912791
# ...    ...   ...         ...         ...       ...       ...       ...
# 13509  218   129    0.999967         0.4       0.0  0.141294  0.324567
# 13510  218   130    0.999879         0.4       0.0  0.132561  0.325326
# 13511  218   131    0.999807         0.4       0.0  0.131182  0.308155
# 13512  218   132    0.833191         0.6  0.060269  0.192131  0.364597
# 13513  218   133    0.595294         0.8  0.238089  0.016639  0.079138
#
#         sensor4   sensor5   sensor6  ...  sensor13  sensor14  sensor17  \
# 0      0.195316       0.0  0.000629  ...  0.992783  0.554348  0.273684
# 1      0.895972       1.0  0.999371  ...  0.992535  0.683409  0.936842
# 2       0.23218       0.0       0.0  ...  0.992452  0.547969  0.284211
# 3      0.218059  0.146592  0.144025  ...   0.99248  0.507265  0.305263
# 4      0.867028       1.0       1.0  ...  0.992204    0.6681  0.915789
# ...         ...       ...       ...  ...       ...       ...       ...
# 13509  0.285659       0.0  0.000629  ...  0.990772  0.499138  0.315789
# 13510  0.273016       0.0       0.0  ...  0.990469  0.497201  0.305263
# 13511  0.292247       0.0  0.000629  ...  0.990607  0.498807  0.326316
# 13512   0.28096  0.146592  0.144025  ...   0.99124  0.452692  0.357895
# 13513  0.095139  0.293184  0.208805  ...  0.000083  0.018073  0.073684
#
#        sensor18 sensor19  sensor20  sensor21 MAX_CYCLE    y_test     y_pre
# 0      0.627907      1.0  0.013402  0.010187            1.000000  1.000000
# 1           1.0      1.0  0.990034  0.989092            1.000000  1.000000
# 2      0.627907      1.0  0.011684  0.023019            1.000000  1.000000
# 3      0.651163      1.0  0.161512   0.16068            1.000000  1.000000
# 4           1.0      1.0  0.985911  0.996507            1.000000  0.866667
# ...         ...      ...       ...       ...       ...       ...       ...
# 13509  0.627907      1.0  0.011684  0.009843            0.033333  0.000000
# 13510  0.627907      1.0  0.005842  0.008446            0.025000  0.016667
# 13511  0.627907      1.0  0.004811  0.004077            0.016667  0.016667
# 13512  0.651163      1.0  0.153608  0.145987            0.008333  0.141667
# 13513       0.0      0.0  0.136082   0.13659            0.000000  0.016667
#
# [13514 rows x 25 columns]

# %%
a=ncpy[ncpy['e_id']==154]
plt.plot(a['cycle'],a['y_test'],color='blue')
plt.plot(a['cycle'],a['y_pre'],color='red')
plt.xlabel('CYCLE')
plt.ylabel('RUL') 
plt.title('compare')
plt.legend() 
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
Test_yprd = fit.predict(ntest_cpy)
ntest['test_rul']=pd.DataFrame(Test_yprd)
fig = plt.figure(figsize=(30,10))
plt.plot(Test_yprd,c='red',label='prediction')
plt.legend()
plt.show()

# %%
a=ntest[ntest['e_id']==5]
plt.plot(a['cycle'],a['test_rul'],color='red')
plt.xlabel('CYCLE')
plt.ylabel('RUL') 
plt.legend() 
plt.show()
# Out:
# No handles with labels found to put in legend.
